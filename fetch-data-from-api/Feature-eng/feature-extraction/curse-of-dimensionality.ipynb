# %% [markdown]
# cols=features=dimensions
#
# curse of dimensionality means that the cols are not incr accuracy are not helping rather incr complexity or decr accuracy
#
# if higher dimensions then sparcity of data na lidhe accuracy ochi thase
#
# so model ni performance decreases
# computation incr(time space complexity incr like 2d ma space calc karvu is easier than calc in 7d )
#
# so we just select optimal cols with dimentionality reduction
#
# Dimensionality Reduction methods:
# 1. Feature Selection --> forward and backward selection
# 2. Feature Extraction --> pca(principle component analysis),lda,tsne --> pca ma nava cols banaviye from old cols j juna cols na linear combination ma hoy
