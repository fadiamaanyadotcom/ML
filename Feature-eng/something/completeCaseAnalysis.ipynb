# %% [markdown]
# to handle missing values we can either delete the whole row  with one cell with missing value but that leads to loss of imp data as well
#
# or impute --> univariate or multivariate
#
# UNIVARIATE
# 2 techniques for numerical and categorical
#
# 1. NUMERICAL
#     1. mean/median
#     2. Random
#     3. end of distribution
# 2. CATEGORICAL
#    1. mode
#    2. missing(legit word)
#
# MULTIVARIATE
#
# 1. KNN imputer
# 2. Iterative imputer --> MICE algo pr kaam kare

# %% [markdown]
# Complete case analysis means analysing for only those observations for which there is info in all variables in dataset
#
# CAN BE USED WHEN-->
#
# when data is randomly missing like let say 50 values in age col is missing but ae specific starting k mid k ending na na hoy(THE MISSING DATA SHOULD BE JUST 5 PERCENT)
#
# ADVANTAGES:-
#  1. easy to implement as no data manipulation required
#  2. if missing values are random then it preserves variable distribution
#
# DISADVANTAGES:-
#  1. it can exclude large fraction of original dataset(if like missing in big quant so 5 percent rule is there)
#  2. excluded info might be useful
#  3. model wont know how to deal with missing values if it occurs irl

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_science_job.csv')

# %%
df.isnull().mean()*100 # bcz isnull just give 1 for true and 0 for false so mean will give that how much missing data is there and times 100 will give the percentage
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
df.shape
# Out:
# (19158, 13)

# %%
cols = [var for var in df.columns if df[var].isnull().mean() < 0.05 and df[var].isnull().mean() > 0]

# %%
len(df[cols].dropna())/len(df) # to check the loss of data(rows)
# Out:
# 0.8968577095730244

# %%
new_df = df[cols].dropna()

# %%
new_df.shape
# Out:
# (17182, 5)

# %% [markdown]
# SO FOR CCA NUMERICAL DATA WE PLOT HISTOGRAM AND PDE FUNCTION AND BEFORE AND AFTER IS SAME THEN CCA KARAY
#
# AND IF FOR CATEGORICAL DATA MA RATIO OF EACH COL BEFORE AND AFTER SAME THEN CCA USE KARAY

# %%
df['education_level'].value_counts()
# Out:
# education_level
# Graduate          11598
# Masters            4361
# High School        2017
# Phd                 414
# Primary School      308
# Name: count, dtype: int64

# %%
new_df.hist(bins=50, density=True, figsize=(12,12))
plt.show()

# %%
fig = plt.figure()
ax=fig.add_subplot(111)
